# %% [markdown]
# # Modeling
#
# This project focuses on exploratory analysis and business intelligence workflows.
# A predictive churn model was not included, as the primary goal was to analyze
# customer behavior and build a dashboard rather than develop a machine learning model.
