# %% [markdown]
# ## Initial Insights
#
# Based on the exploratory analysis:
#
# - Customers with **Month-to-month contracts** churn significantly more than those with 1-year or 2-year contracts.
# - Lower **SatisfactionScore** strongly correlates with higher churn.
# - Higher **MonthlyCharges** appear to increase churn probability.
# - Customers with many **SupportTicketsLast6M** show higher churn rates.
# - Tenure is a strong stabilizing factor: new customers churn more.
#
# These findings will guide the Excel and Tableau phases, where we will build KPIs and segmentations.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="Churn", y="MonthlyCharges")
plt.title("Monthly Charges by Churn")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="Churn", y="SatisfactionScore")
plt.title("Satisfaction Score by Churn")
plt.show()

# %%
sns.countplot(data=df, x="ContractType", hue="Churn")
plt.title("Churn by Contract Type")
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df, x="Churn")
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

plt.figure(figsize=(14, 8))
df[numeric_cols].boxplot()
plt.xticks(rotation=45)
plt.show()

# %%
df.hist(figsize=(14, 10), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# No missing values were found in the dataset. This is expected since the dataset was synthetically generated.

# %%
df.isnull().sum()

# %%
for col in df.select_dtypes(include="object").columns:
    print(f"\nValue counts for {col}:")
    print(df[col].value_counts())

# %%
df.describe(include="object")

# %%
df.describe()

# %%
df.info()

# %%
df.shape

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

df = pd.read_csv("../data/customer_churn_dataset.csv")
df.head()

# %% [markdown]
# # Exploratory Data Analysis (EDA) – Customer Churn Dataset
#
# In this notebook, we explore the synthetic telecom churn dataset created in Phase 1.
# The goal is to:
# - Understand the structure and quality of the data
# - Identify key patterns and relationships
# - Explore factors that influence customer churn
# - Prepare insights for Excel and Tableau phases
